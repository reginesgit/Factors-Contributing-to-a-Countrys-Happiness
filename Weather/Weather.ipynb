# %%
import pandas as pd
import numpy as np
import requests

# Dependencies and Setup
import matplotlib.pyplot as plt
import gmaps
import os
import json

# Import API key
from config import g_key

# Import API key
from config import weather_api_key

# %%
# Create reference to CSV file containing countries and their capitals
csv_path = "Resources/Countries_and_Capitals.csv"
# Import the CSV into a pandas DataFrame
capitals_countries_df = pd.read_csv(csv_path, low_memory=False)
# Rename columns to allow merging in next steps
capitals_countries = capitals_countries_df.rename(columns={"CountryName":"Country", "CapitalName":"City"})
capitals_countries
# Out:
#                                       Country               City  \
# 0                                  Somaliland           Hargeisa
# 1    South Georgia and South Sandwich Islands  King Edward Point
# 2         French Southern and Antarctic Lands  Port-aux-Français
# 3                                   Palestine          Jerusalem
# 4                               Aland Islands          Mariehamn
# ..                                        ...                ...
# 240                           Northern Cyprus      North Nicosia
# 241                                 Hong Kong                NaN
# 242         Heard Island and McDonald Islands                NaN
# 243            British Indian Ocean Territory       Diego Garcia
# 244                                     Macau                NaN
#
#      CapitalLatitude  CapitalLongitude CountryCode ContinentName
# 0           9.550000         44.050000         NaN        Africa
# 1         -54.283333        -36.500000          GS    Antarctica
# 2         -49.350000         70.216667          TF    Antarctica
# 3          31.766667         35.233333          PS          Asia
# 4          60.116667         19.900000          AX        Europe
# ..               ...               ...         ...           ...
# 240        35.183333         33.366667         NaN        Europe
# 241         0.000000          0.000000          HK          Asia
# 242         0.000000          0.000000          HM    Antarctica
# 243        -7.300000         72.400000          IO        Africa
# 244         0.000000          0.000000          MO          Asia
#
# [245 rows x 6 columns]

# %%
# Create a list of capital cities to retrieve weather report for
cities = capitals_countries["City"].tolist()
cities
# Out:
# ['Hargeisa',
#  'King Edward Point',
#  'Port-aux-Français',
#  'Jerusalem',
#  'Mariehamn',
#  'Yaren',
#  'Marigot',
#  'Atafu',
#  'El-Aaiún',
#  'Kabul',
#  'Tirana',
#  'Algiers',
#  'Pago Pago',
#  'Andorra la Vella',
#  'Luanda',
#  'The Valley',
#  "Saint John's",
#  'Buenos Aires',
#  'Yerevan',
#  'Oranjestad',
#  'Canberra',
#  'Vienna',
#  'Baku',
#  'Nassau',
#  'Manama',
#  'Dhaka',
#  'Bridgetown',
#  'Minsk',
#  'Brussels',
#  'Belmopan',
#  'Porto-Novo',
#  'Hamilton',
#  'Thimphu',
#  'La Paz',
#  'Sarajevo',
#  'Gaborone',
#  'Brasilia',
#  'Road Town',
#  'Bandar Seri Begawan',
#  'Sofia',
#  'Ouagadougou',
#  'Rangoon',
#  'Bujumbura',
#  'Phnom Penh',
#  'Yaounde',
#  'Ottawa',
#  'Praia',
#  'George Town',
#  'Bangui',
#  "N'Djamena",
#  'Santiago',
#  'Beijing',
#  'The Settlement',
#  'West Island',
#  'Bogota',
#  'Moroni',
#  'Kinshasa',
#  'Brazzaville',
#  'Avarua',
#  'San Jose',
#  'Yamoussoukro',
#  'Zagreb',
#  'Havana',
#  'Willemstad',
#  'Nicosia',
#  'Prague',
#  'Copenhagen',
#  'Djibouti',
#  'Roseau',
#  'Santo Domingo',
#  'Quito',
#  'Cairo',
#  'San Salvador',
#  'Malabo',
#  'Asmara',
#  'Tallinn',
#  'Addis Ababa',
#  'Stanley',
#  'Torshavn',
#  'Suva',
#  'Helsinki',
#  'Paris',
#  'Papeete',
#  'Libreville',
#  'Banjul',
#  'Tbilisi',
#  'Berlin',
#  'Accra',
#  'Gibraltar',
#  'Athens',
#  'Nuuk',
#  "Saint George's",
#  'Hagatna',
#  'Guatemala City',
#  'Saint Peter Port',
#  'Conakry',
#  'Bissau',
#  'Georgetown',
#  'Port-au-Prince',
#  'Vatican City',
#  'Tegucigalpa',
#  'Budapest',
#  'Reykjavik',
#  'New Delhi',
#  'Jakarta',
#  'Tehran',
#  'Baghdad',
#  'Dublin',
#  'Douglas',
#  'Jerusalem',
#  'Rome',
#  'Kingston',
#  'Tokyo',
#  'Saint Helier',
#  'Amman',
#  'Astana',
#  'Nairobi',
#  'Tarawa',
#  'Pyongyang',
#  'Seoul',
#  'Pristina',
#  'Kuwait City',
#  'Bishkek',
#  'Vientiane',
#  'Riga',
#  'Beirut',
#  'Maseru',
#  'Monrovia',
#  'Tripoli',
#  'Vaduz',
#  'Vilnius',
#  'Luxembourg',
#  'Skopje',
#  'Antananarivo',
#  'Lilongwe',
#  'Kuala Lumpur',
#  'Male',
#  'Bamako',
#  'Valletta',
#  'Majuro',
#  'Nouakchott',
#  'Port Louis',
#  'Mexico City',
#  'Palikir',
#  'Chisinau',
#  'Monaco',
#  'Ulaanbaatar',
#  'Podgorica',
#  'Plymouth',
#  'Rabat',
#  'Maputo',
#  'Windhoek',
#  'Kathmandu',
#  'Amsterdam',
#  'Noumea',
#  'Wellington',
#  'Managua',
#  'Niamey',
#  'Abuja',
#  'Alofi',
#  'Kingston',
#  'Saipan',
#  'Oslo',
#  'Muscat',
#  'Islamabad',
#  'Melekeok',
#  'Panama City',
#  'Port Moresby',
#  'Asuncion',
#  'Lima',
#  'Manila',
#  'Adamstown',
#  'Warsaw',
#  'Lisbon',
#  'San Juan',
#  'Doha',
#  'Bucharest',
#  'Moscow',
#  'Kigali',
#  'Gustavia',
#  'Jamestown',
#  'Basseterre',
#  'Castries',
#  'Saint-Pierre',
#  'Kingstown',
#  'Apia',
#  'San Marino',
#  'Sao Tome',
#  'Riyadh',
#  'Dakar',
#  'Belgrade',
#  'Victoria',
#  'Freetown',
#  'Singapore',
#  'Philipsburg',
#  'Bratislava',
#  'Ljubljana',
#  'Honiara',
#  'Mogadishu',
#  'Pretoria',
#  'Juba',
#  'Madrid',
#  'Colombo',
#  'Khartoum',
#  'Paramaribo',
#  'Longyearbyen',
#  'Mbabane',
#  'Stockholm',
#  'Bern',
#  'Damascus',
#  'Taipei',
#  'Dushanbe',
#  'Dar es Salaam',
#  'Bangkok',
#  'Dili',
#  'Lome',
#  "Nuku'alofa",
#  'Port of Spain',
#  'Tunis',
#  'Ankara',
#  'Ashgabat',
#  'Grand Turk',
#  'Funafuti',
#  'Kampala',
#  'Kyiv',
#  'Abu Dhabi',
#  'London',
#  'Washington',
#  'Montevideo',
#  'Tashkent',
#  'Port-Vila',
#  'Caracas',
#  'Hanoi',
#  'Charlotte Amalie',
#  'Mata-Utu',
#  'Sanaa',
#  'Lusaka',
#  'Harare',
#  'Washington',
#  nan,
#  'North Nicosia',
#  nan,
#  nan,
#  'Diego Garcia',
#  nan]

# %%
w_cities = []
temps = []
humidities = []
cloudiness = []
wind_speeds = []
dates = []


url = "http://api.openweathermap.org/data/2.5/weather?"

for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&q={city}&units=imperial"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        w_cities.append(weather_json["name"])
        temps.append(weather_json["main"]["temp"])
        humidities.append(weather_json["main"]["humidity"])
        cloudiness.append(weather_json["clouds"]["all"])
        wind_speeds.append(weather_json["wind"]["speed"])
        dates.append(weather_json["dt"])
    except:
        print(f"{city} not found, skipping...")
# Out:
# King Edward Point not found, skipping...
# Atafu not found, skipping...
# Grand Turk not found, skipping...
# North Nicosia not found, skipping...
# Diego Garcia not found, skipping...

# %%
# Validate lengths of returned arrays to prepare merging
# len(cities)
# len(w_cities)
# len(temps)
# len(humidities)
# len(cloudiness)
# len(wind_speeds)
# len(countries)
len(dates)
# Out:
# 240

# %%
# Create dictionary of weather data for cities
weather_dict = {"City": w_cities, "Temp": temps, "Humidity": humidities, "Cloudiness": cloudiness, "Wind Speed": wind_speeds, "Date": dates}
# Create dataframe of weather dictionary
weather_data = pd.DataFrame(weather_dict)
# Export dataframe to CSV
weather_data.to_csv("Resources/weather_data.csv", encoding="utf-8", index=True)
# Show dataframe
weather_data
# Out:
#                   City   Temp  Humidity  Cloudiness  Wind Speed        Date
# 0             Hargeisa  60.06        91          87       16.96  1613785213
# 1    Port-aux-Français  38.28        93          68       19.55  1613785213
# 2            Jerusalem  43.00        95           5        4.68  1613785154
# 3            Mariehamn  33.80       100          90        6.91  1613785089
# 4                Yaren  81.36        78           5       15.77  1613785213
# ..                 ...    ...       ...         ...         ...         ...
# 235         Washington  29.19        84         100        1.28  1613785226
# 236                Nan  62.60        94           4        2.30  1613785227
# 237                Nan  62.60        94           4        2.30  1613785227
# 238                Nan  62.60        94           4        2.30  1613785227
# 239                Nan  62.60        94           4        2.30  1613785227
#
# [240 rows x 6 columns]

# %%
weather_data.dropna(how='any')
weather_data
# Out:
#                   City   Temp  Humidity  Cloudiness  Wind Speed        Date
# 0             Hargeisa  60.06        91          87       16.96  1613785213
# 1    Port-aux-Français  38.28        93          68       19.55  1613785213
# 2            Jerusalem  43.00        95           5        4.68  1613785154
# 3            Mariehamn  33.80       100          90        6.91  1613785089
# 4                Yaren  81.36        78           5       15.77  1613785213
# ..                 ...    ...       ...         ...         ...         ...
# 235         Washington  29.19        84         100        1.28  1613785226
# 236                Nan  62.60        94           4        2.30  1613785227
# 237                Nan  62.60        94           4        2.30  1613785227
# 238                Nan  62.60        94           4        2.30  1613785227
# 239                Nan  62.60        94           4        2.30  1613785227
#
# [240 rows x 6 columns]

# %%
weather_data.loc[weather_data["City"] == "Nan", :]
weather_data.drop([236, 237, 238, 239])
# Out:
#                   City   Temp  Humidity  Cloudiness  Wind Speed        Date
# 0             Hargeisa  60.06        91          87       16.96  1613785213
# 1    Port-aux-Français  38.28        93          68       19.55  1613785213
# 2            Jerusalem  43.00        95           5        4.68  1613785154
# 3            Mariehamn  33.80       100          90        6.91  1613785089
# 4                Yaren  81.36        78           5       15.77  1613785213
# ..                 ...    ...       ...         ...         ...         ...
# 231           Mata-Utu  83.57        70         100        5.66  1613785227
# 232              Sanaa  54.91        41          26        1.54  1613785227
# 233             Lusaka  64.04        98         100        6.46  1613785227
# 234             Harare  63.00        88         100       11.01  1613785227
# 235         Washington  29.19        84         100        1.28  1613785226
#
# [236 rows x 6 columns]

# %%
merge_weather_countries = pd.merge(weather_data, capitals_countries, on="City", how="left")
merge_weather_countries
# Out:
#                   City   Temp  Humidity  Cloudiness  Wind Speed        Date  \
# 0             Hargeisa  60.06        91          87       16.96  1613785213
# 1    Port-aux-Français  38.28        93          68       19.55  1613785213
# 2            Jerusalem  43.00        95           5        4.68  1613785154
# 3            Jerusalem  43.00        95           5        4.68  1613785154
# 4            Mariehamn  33.80       100          90        6.91  1613785089
# ..                 ...    ...       ...         ...         ...         ...
# 241         Washington  29.19        84         100        1.28  1613785226
# 242                Nan  62.60        94           4        2.30  1613785227
# 243                Nan  62.60        94           4        2.30  1613785227
# 244                Nan  62.60        94           4        2.30  1613785227
# 245                Nan  62.60        94           4        2.30  1613785227
#
#                                  Country  CapitalLatitude  CapitalLongitude  \
# 0                             Somaliland         9.550000         44.050000
# 1    French Southern and Antarctic Lands       -49.350000         70.216667
# 2                              Palestine        31.766667         35.233333
# 3                                 Israel        31.766667         35.233333
# 4                          Aland Islands        60.116667         19.900000
# ..                                   ...              ...               ...
# 241            US Minor Outlying Islands        38.883333        -77.000000
# 242                                  NaN              NaN               NaN
# 243                                  NaN              NaN               NaN
# 244                                  NaN              NaN               NaN
# 245                                  NaN              NaN               NaN
#
#     CountryCode ContinentName
# 0           NaN        Africa
# 1            TF    Antarctica
# 2            PS          Asia
# 3            IL          Asia
# 4            AX        Europe
# ..          ...           ...
# 241          UM     Australia
# 242         NaN           NaN
# 243         NaN           NaN
# 244         NaN           NaN
# 245         NaN           NaN
#
# [246 rows x 11 columns]

# %%
merge_weather_countries.loc[merge_weather_countries["City"] == "Nan", :]
merge_weather_countries.drop([242, 243, 244, 245])
# Out:
#                   City   Temp  Humidity  Cloudiness  Wind Speed        Date  \
# 0             Hargeisa  60.06        91          87       16.96  1613785213
# 1    Port-aux-Français  38.28        93          68       19.55  1613785213
# 2            Jerusalem  43.00        95           5        4.68  1613785154
# 3            Jerusalem  43.00        95           5        4.68  1613785154
# 4            Mariehamn  33.80       100          90        6.91  1613785089
# ..                 ...    ...       ...         ...         ...         ...
# 237              Sanaa  54.91        41          26        1.54  1613785227
# 238             Lusaka  64.04        98         100        6.46  1613785227
# 239             Harare  63.00        88         100       11.01  1613785227
# 240         Washington  29.19        84         100        1.28  1613785226
# 241         Washington  29.19        84         100        1.28  1613785226
#
#                                  Country  CapitalLatitude  CapitalLongitude  \
# 0                             Somaliland         9.550000         44.050000
# 1    French Southern and Antarctic Lands       -49.350000         70.216667
# 2                              Palestine        31.766667         35.233333
# 3                                 Israel        31.766667         35.233333
# 4                          Aland Islands        60.116667         19.900000
# ..                                   ...              ...               ...
# 237                                Yemen        15.350000         44.200000
# 238                               Zambia       -15.416667         28.283333
# 239                             Zimbabwe       -17.816667         31.033333
# 240                        United States        38.883333        -77.000000
# 241            US Minor Outlying Islands        38.883333        -77.000000
#
#     CountryCode    ContinentName
# 0           NaN           Africa
# 1            TF       Antarctica
# 2            PS             Asia
# 3            IL             Asia
# 4            AX           Europe
# ..          ...              ...
# 237          YE             Asia
# 238          ZM           Africa
# 239          ZW           Africa
# 240          US  Central America
# 241          UM        Australia
#
# [242 rows x 11 columns]

# %%
# Remove duplicate cities
cleaned_weather_countries = merge_weather_countries.drop_duplicates(subset="City", keep='first', inplace=False, ignore_index=False)
# cleaned_weather_countries

cleaned_weather_countries_reordered = cleaned_weather_countries[["Country", "ContinentName", "City","CapitalLatitude", "CapitalLongitude", "Temp", "Cloudiness", "Wind Speed", "Humidity"]]

cleaned_weather_countries_reordered.loc[cleaned_weather_countries_reordered["City"] == "Nan", :]
cleaned_weather_countries_reordered.drop([242])
# Out:
#                                  Country  ContinentName               City  \
# 0                             Somaliland         Africa           Hargeisa
# 1    French Southern and Antarctic Lands     Antarctica  Port-aux-Français
# 2                              Palestine           Asia          Jerusalem
# 4                          Aland Islands         Europe          Mariehamn
# 5                                  Nauru      Australia              Yaren
# ..                                   ...            ...                ...
# 235                    US Virgin Islands  North America   Charlotte Amalie
# 236                    Wallis and Futuna      Australia           Mata-Utu
# 237                                Yemen           Asia              Sanaa
# 238                               Zambia         Africa             Lusaka
# 239                             Zimbabwe         Africa             Harare
#
#      CapitalLatitude  CapitalLongitude   Temp  Cloudiness  Wind Speed  \
# 0           9.550000         44.050000  60.06          87       16.96
# 1         -49.350000         70.216667  38.28          68       19.55
# 2          31.766667         35.233333  43.00           5        4.68
# 4          60.116667         19.900000  33.80          90        6.91
# 5          -0.547700        166.920867  81.36           5       15.77
# ..               ...               ...    ...         ...         ...
# 235        18.350000        -64.933333  76.41           1       10.36
# 236       -13.950000       -171.933333  83.57         100        5.66
# 237        15.350000         44.200000  54.91          26        1.54
# 238       -15.416667         28.283333  64.04         100        6.46
# 239       -17.816667         31.033333  63.00         100       11.01
#
#      Humidity
# 0          91
# 1          93
# 2          95
# 4         100
# 5          78
# ..        ...
# 235        61
# 236        70
# 237        41
# 238        98
# 239        88
#
# [232 rows x 9 columns]

# %%
file = "../Happiness/Resources/avg_happiness.csv"
merge_ave_happiness = pd.read_csv(file)
merge_ave_happiness.head()
# Out:
#        Country  Happiness Score_2015  Happiness Score_2016  \
# 0  Switzerland                 7.587                 7.509
# 1      Iceland                 7.561                 7.501
# 2      Denmark                 7.527                 7.526
# 3       Norway                 7.522                 7.498
# 4       Canada                 7.427                 7.404
#
#    Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 0                 7.494                 7.487                 7.480
# 1                 7.504                 7.495                 7.494
# 2                 7.522                 7.555                 7.600
# 3                 7.537                 7.594                 7.554
# 4                 7.316                 7.328                 7.278
#
#    Avg Happiness
# 0         7.5114
# 1         7.5110
# 2         7.5460
# 3         7.5410
# 4         7.3506

# %%
merge_happiness_weather = pd.merge(merge_ave_happiness, cleaned_weather_countries_reordered, on="Country", how="left")
merge_happiness_weather
# Out:
#          Country  Happiness Score_2015  Happiness Score_2016  \
# 0    Switzerland                 7.587                 7.509
# 1        Iceland                 7.561                 7.501
# 2        Denmark                 7.527                 7.526
# 3         Norway                 7.522                 7.498
# 4         Canada                 7.427                 7.404
# ..           ...                   ...                   ...
# 136       Rwanda                 3.465                 3.515
# 137        Benin                 3.340                 3.484
# 138        Syria                 3.006                 3.069
# 139      Burundi                 2.905                 2.905
# 140         Togo                 2.839                 3.303
#
#      Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 0                   7.494                 7.487                 7.480
# 1                   7.504                 7.495                 7.494
# 2                   7.522                 7.555                 7.600
# 3                   7.537                 7.594                 7.554
# 4                   7.316                 7.328                 7.278
# ..                    ...                   ...                   ...
# 136                 3.471                 3.408                 3.334
# 137                 3.657                 4.141                 4.883
# 138                 3.462                 3.462                 3.462
# 139                 2.905                 2.905                 3.775
# 140                 3.495                 3.999                 4.085
#
#      Avg Happiness    ContinentName        City  CapitalLatitude  \
# 0           7.5114           Europe        Bern        46.916667
# 1           7.5110           Europe   Reykjavik        64.150000
# 2           7.5460           Europe  Copenhagen        55.666667
# 3           7.5410           Europe        Oslo        59.916667
# 4           7.3506  Central America      Ottawa        45.416667
# ..             ...              ...         ...              ...
# 136         3.4386           Africa      Kigali        -1.950000
# 137         3.9010           Africa  Porto-Novo         6.483333
# 138         3.2922             Asia    Damascus        33.500000
# 139         3.0790           Africa   Bujumbura        -3.366667
# 140         3.5442              NaN         NaN              NaN
#
#      CapitalLongitude   Temp  Cloudiness  Wind Speed  Humidity
# 0            7.466667  37.62        22.0        1.14     100.0
# 1          -21.950000  31.78         0.0        7.00      80.0
# 2           12.583333  37.13        90.0       10.36      93.0
# 3           10.750000  34.43       100.0        1.99      85.0
# 4          -75.700000  17.37        90.0        2.30      92.0
# ..                ...    ...         ...         ...       ...
# 136         30.050000  59.07       100.0        0.96      93.0
# 137          2.616667  78.39         0.0        5.75      80.0
# 138         36.300000  32.00        10.0        4.61      93.0
# 139         29.350000  70.36       100.0        1.99      72.0
# 140               NaN    NaN         NaN         NaN       NaN
#
# [141 rows x 15 columns]

# %%
merge_happiness_weather.loc[merge_happiness_weather["City"] == "NaN", :]
# Out:
# Empty DataFrame
# Columns: [Country, Happiness Score_2015, Happiness Score_2016, Happiness Score_2017, Happiness Score_2018, Happiness Score_2019, Avg Happiness, ContinentName, City, CapitalLatitude, CapitalLongitude, Temp, Cloudiness, Wind Speed, Humidity]
# Index: []

# %%
# Export dataframe to CSV
merge_happiness_weather.to_csv("Resources/happiness_weather.csv", encoding="utf-8", index=True)

# %%
sorted_happiness_weather = merge_happiness_weather.sort_values(["Avg Happiness"], ascending=False)
sorted_happiness_weather
# Out:
#          Country  Happiness Score_2015  Happiness Score_2016  \
# 2        Denmark                 7.527                 7.526
# 3         Norway                 7.522                 7.498
# 5        Finland                 7.406                 7.413
# 0    Switzerland                 7.587                 7.509
# 1        Iceland                 7.561                 7.501
# ..           ...                   ...                   ...
# 135  Afghanistan                 3.575                 3.360
# 129     Tanzania                 3.781                 3.666
# 136       Rwanda                 3.465                 3.515
# 138        Syria                 3.006                 3.069
# 139      Burundi                 2.905                 2.905
#
#      Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 2                   7.522                 7.555                 7.600
# 3                   7.537                 7.594                 7.554
# 5                   7.469                 7.632                 7.769
# 0                   7.494                 7.487                 7.480
# 1                   7.504                 7.495                 7.494
# ..                    ...                   ...                   ...
# 135                 3.794                 3.632                 3.203
# 129                 3.349                 3.303                 3.231
# 136                 3.471                 3.408                 3.334
# 138                 3.462                 3.462                 3.462
# 139                 2.905                 2.905                 3.775
#
#      Avg Happiness ContinentName           City  CapitalLatitude  \
# 2           7.5460        Europe     Copenhagen        55.666667
# 3           7.5410        Europe           Oslo        59.916667
# 5           7.5378        Europe       Helsinki        60.166667
# 0           7.5114        Europe           Bern        46.916667
# 1           7.5110        Europe      Reykjavik        64.150000
# ..             ...           ...            ...              ...
# 135         3.5128          Asia          Kabul        34.516667
# 129         3.4660        Africa  Dar es Salaam        -6.800000
# 136         3.4386        Africa         Kigali        -1.950000
# 138         3.2922          Asia       Damascus        33.500000
# 139         3.0790        Africa      Bujumbura        -3.366667
#
#      CapitalLongitude   Temp  Cloudiness  Wind Speed  Humidity
# 2           12.583333  37.13        90.0       10.36      93.0
# 3           10.750000  34.43       100.0        1.99      85.0
# 5           24.933333  23.04        40.0        5.75      74.0
# 0            7.466667  37.62        22.0        1.14     100.0
# 1          -21.950000  31.78         0.0        7.00      80.0
# ..                ...    ...         ...         ...       ...
# 135         69.183333  41.00        75.0        4.61      48.0
# 129         39.283333  78.44        99.0        1.79      78.0
# 136         30.050000  59.07       100.0        0.96      93.0
# 138         36.300000  32.00        10.0        4.61      93.0
# 139         29.350000  70.36       100.0        1.99      72.0
#
# [141 rows x 15 columns]

# %%
happiest_weather_top_10 = sorted_happiness_weather.head(10)
happiest_weather_top_10 = happiest_weather_top_10.reset_index(drop=True)
happiest_weather_top_10
# Out:
#        Country  Happiness Score_2015  Happiness Score_2016  \
# 0      Denmark                 7.527                 7.526
# 1       Norway                 7.522                 7.498
# 2      Finland                 7.406                 7.413
# 3  Switzerland                 7.587                 7.509
# 4      Iceland                 7.561                 7.501
# 5  Netherlands                 7.378                 7.339
# 6       Canada                 7.427                 7.404
# 7       Sweden                 7.364                 7.291
# 8  New Zealand                 7.286                 7.334
# 9    Australia                 7.284                 7.313
#
#    Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 0                 7.522                 7.555                 7.600
# 1                 7.537                 7.594                 7.554
# 2                 7.469                 7.632                 7.769
# 3                 7.494                 7.487                 7.480
# 4                 7.504                 7.495                 7.494
# 5                 7.377                 7.441                 7.488
# 6                 7.316                 7.328                 7.278
# 7                 7.284                 7.314                 7.343
# 8                 7.314                 7.324                 7.307
# 9                 7.284                 7.272                 7.228
#
#    Avg Happiness    ContinentName        City  CapitalLatitude  \
# 0         7.5460           Europe  Copenhagen        55.666667
# 1         7.5410           Europe        Oslo        59.916667
# 2         7.5378           Europe    Helsinki        60.166667
# 3         7.5114           Europe        Bern        46.916667
# 4         7.5110           Europe   Reykjavik        64.150000
# 5         7.4046           Europe   Amsterdam        52.350000
# 6         7.3506  Central America      Ottawa        45.416667
# 7         7.3192           Europe   Stockholm        59.333333
# 8         7.3130        Australia  Wellington       -41.300000
# 9         7.2762        Australia    Canberra       -35.266667
#
#    CapitalLongitude   Temp  Cloudiness  Wind Speed  Humidity
# 0         12.583333  37.13        90.0       10.36      93.0
# 1         10.750000  34.43       100.0        1.99      85.0
# 2         24.933333  23.04        40.0        5.75      74.0
# 3          7.466667  37.62        22.0        1.14     100.0
# 4        -21.950000  31.78         0.0        7.00      80.0
# 5          4.916667  48.65         0.0       11.50      81.0
# 6        -75.700000  17.37        90.0        2.30      92.0
# 7         18.050000  35.51        90.0        9.22      93.0
# 8        174.783333  69.13         5.0       21.85      68.0
# 9        149.133333  82.62         0.0        5.75      41.0

# %%
# Export dataframe to CSV
happiest_weather_top_10.to_csv("Resources/happiness_weather_top10.csv", encoding="utf-8", index=True)
