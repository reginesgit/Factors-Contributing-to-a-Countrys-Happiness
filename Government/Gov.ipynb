# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Store filepath in a variable
Gov_file= "Resources/Database_of_Political_Institutions_2017.csv"

# %%
# Read Data files with the pandas library
Gov_file_df = pd.read_csv(Gov_file, encoding="UTF-8")
Gov_file_df
# Out:
#       countryname  ifs  year  system  yrsoffc  finittrm  yrcurnt  multpl  \
# 0     Turk Cyprus    0  1975  -999.0      1.0    -999.0   -999.0  -999.0
# 1     Turk Cyprus    0  1976     0.0      1.0       1.0      0.0     1.0
# 2     Turk Cyprus    0  1977     0.0      2.0       1.0      4.0     1.0
# 3     Turk Cyprus    0  1978     0.0      3.0       1.0      3.0     1.0
# 4     Turk Cyprus    0  1979     0.0      4.0       1.0      2.0     1.0
# ...           ...  ...   ...     ...      ...       ...      ...     ...
# 7656     Zimbabwe  ZWE  2013     0.0     26.0       1.0      0.0     1.0
# 7657     Zimbabwe  ZWE  2014     0.0     27.0       1.0      4.0     1.0
# 7658     Zimbabwe  ZWE  2015     0.0     28.0       1.0      3.0     1.0
# 7659     Zimbabwe  ZWE  2016     0.0     29.0       1.0      2.0     1.0
# 7660     Zimbabwe  ZWE  2017     0.0     30.0       1.0      1.0     1.0
#
#       military  defmin  ...  dhondt     cl  select fraud  auton  muni  state  \
# ...

# %%
# Print out Column Titles
Gov_file_df.columns
# Out:
# Index(['countryname', 'ifs', 'year', 'system', 'yrsoffc', 'finittrm',
#        'yrcurnt', 'multpl', 'military', 'defmin', 'percent1', 'percentl',
#        'prtyin', 'execme', 'execrlc', 'execnat', 'execrurl', 'execreg',
#        'execrel', 'execage', 'allhouse', 'nonchief', 'totalseats', 'gov1me',
#        'gov1seat', 'gov1vote', 'gov1rlc', 'gov1nat', 'gov1rurl', 'gov1reg',
#        'gov1rel', 'gov1age', 'gov2me', 'gov2seat', 'gov2vote', 'gov2rlc',
#        'gov2nat', 'gov2rurl', 'gov2reg', 'gov2rel', 'gov2age', 'gov3me',
#        'gov3seat', 'gov3vote', 'gov3rlc', 'gov3nat', 'gov3rurl', 'gov3reg',
#        'gov3rel', 'gov3age', 'govoth', 'govothst', 'govothvt', 'opp1me',
#        'opp1seat', 'opp1vote', 'opp1rlc', 'opp1nat', 'opp1rurl', 'opp1reg',
#        'opp1rel', 'opp1age', 'opp2me', 'opp2seat', 'opp2vote', 'opp3me',
#        'opp3seat', 'opp3vote', 'oppoth', 'oppothst', 'oppothvt', 'ulprty',
#        'numul', 'ulvote', 'oppmajh', 'oppmajs', 'dateleg', 'dateexec',
# ...

# %%
# Remove columns not being used for analysis
Gov_file_df.drop(columns = ['ifs', 'yrsoffc', 'finittrm',
       'yrcurnt', 'multpl', 'military', 'defmin', 'percent1', 'percentl',
       'prtyin', 'execme', 'execrlc', 'execnat', 'execrurl', 'execreg',
       'execrel', 'execage', 'allhouse', 'nonchief', 'totalseats', 'gov1me',
       'gov1seat', 'gov1vote', 'gov1rlc', 'gov1nat', 'gov1rurl', 'gov1reg',
       'gov1rel', 'gov1age', 'gov2me', 'gov2seat', 'gov2vote', 'gov2rlc',
       'gov2nat', 'gov2rurl', 'gov2reg', 'gov2rel', 'gov2age', 'gov3me',
       'gov3seat', 'gov3vote', 'gov3rlc', 'gov3nat', 'gov3rurl', 'gov3reg',
       'gov3rel', 'gov3age', 'govoth', 'govothst', 'govothvt', 'opp1me',
       'opp1seat', 'opp1vote', 'opp1rlc', 'opp1nat', 'opp1rurl', 'opp1reg',
       'opp1rel', 'opp1age', 'opp2me', 'opp2seat', 'opp2vote', 'opp3me',
       'opp3seat', 'opp3vote', 'oppoth', 'oppothst', 'oppothvt', 'ulprty',
       'numul', 'ulvote', 'oppmajh', 'oppmajs', 'dateleg', 'dateexec',
       'legelec', 'exelec', 'liec', 'eiec', 'mdmh', 'mdms', 'ssh', 'pluralty',
       'pr', 'housesys', 'sensys', 'thresh', 'dhondt', 'cl', 'select', 'fraud',
       'auton', 'muni', 'state', 'author', 'stconst', 'gwno'], inplace = True)
Gov_file_df
# Out:
#       countryname  year  system
# 0     Turk Cyprus  1975  -999.0
# 1     Turk Cyprus  1976     0.0
# 2     Turk Cyprus  1977     0.0
# 3     Turk Cyprus  1978     0.0
# 4     Turk Cyprus  1979     0.0
# ...           ...   ...     ...
# 7656     Zimbabwe  2013     0.0
# 7657     Zimbabwe  2014     0.0
# 7658     Zimbabwe  2015     0.0
# 7659     Zimbabwe  2016     0.0
# 7660     Zimbabwe  2017     0.0
#
# [7661 rows x 3 columns]

# %%
# Only keep rows for year 2017
Gov_file_df = Gov_file_df[Gov_file_df['year']== 2017]
Gov_file_df
# Out:
#       countryname  year  system
# 42    Turk Cyprus  2017     0.0
# 86    Afghanistan  2017     0.0
# 129        Angola  2017     0.0
# 172       Albania  2017     2.0
# 215           UAE  2017     0.0
# ...           ...   ...     ...
# 7496   Yugoslavia  2017  -999.0
# 7540    S. Africa  2017     1.0
# 7574  Congo (DRC)  2017     0.0
# 7617       Zambia  2017     0.0
# 7660     Zimbabwe  2017     0.0
#
# [179 rows x 3 columns]

# %%
# Rename Columns 
Gov_file_df.rename(columns = {"countryname" : "Country",
                              "system" : "Form of Government",}, inplace = True)
                              
Gov_file_df
# Out:
# /Users/sarapatel/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#           Country  year  Form of Government
# 42    Turk Cyprus  2017                 0.0
# 86    Afghanistan  2017                 0.0
# 129        Angola  2017                 0.0
# 172       Albania  2017                 2.0
# 215           UAE  2017                 0.0
# ...           ...   ...                 ...
# 7496   Yugoslavia  2017              -999.0
# 7540    S. Africa  2017                 1.0
# 7574  Congo (DRC)  2017                 0.0
# 7617       Zambia  2017                 0.0
# 7660     Zimbabwe  2017                 0.0
#
# [179 rows x 3 columns]

# %%
# Find Invalid forms of Governments 
invalid = Gov_file_df["Form of Government"] == -999

#Drop Invalid Goverments by index -  inplace 

Gov_file_df.drop(Gov_file_df[invalid].index, inplace = True)
Gov_file_df.head()
# Out:
# /Users/sarapatel/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          Country  year  Form of Government
# 42   Turk Cyprus  2017                 0.0
# 86   Afghanistan  2017                 0.0
# 129       Angola  2017                 0.0
# 172      Albania  2017                 2.0
# 215          UAE  2017                 0.0

# %%
# Drop all rows with 'NaN'
Gov_file_df = Gov_file_df.dropna()
Gov_file_df.reset_index(inplace = True, drop = True)
Gov_file_df
# Out:
#          Country  year  Form of Government
# 0    Turk Cyprus  2017                 0.0
# 1    Afghanistan  2017                 0.0
# 2         Angola  2017                 0.0
# 3        Albania  2017                 2.0
# 4            UAE  2017                 0.0
# ..           ...   ...                 ...
# 169        Samoa  2017                 2.0
# 170    S. Africa  2017                 1.0
# 171  Congo (DRC)  2017                 0.0
# 172       Zambia  2017                 0.0
# 173     Zimbabwe  2017                 0.0
#
# [174 rows x 3 columns]

# %% [markdown]
# * Presidential (0), chief executive is chosen by the people to serve a limited term in office with a distinct
#  separation of powers (the executive branch) as well as specific limitations on exactly what he/she can do while
# in office. Systems with presidents who are elected directly or by an electoral college
# #(whose only function is to elect the president) and in cases where there is no prime minister
# * Assembly-elected President (1) any means of executive selection not involving A Direct Or Indirect mandate from An electorate
# when that assembly or group cannot easily recall him
# * Parliamentary (2), Countries in which the legislature elects the chief executive.
# in this system, the executive and legislative branches of government are combined and the political head of state
# is chosen from within the legislature

# %%
# create a new column with string values for Gov float to string
Gov_file_df["Government"] = ""

Gov_file_df.loc[Gov_file_df["Form of Government"] == 0.0, "Government"] = "Direct Presidential"
Gov_file_df.loc[Gov_file_df["Form of Government"] == 1.0, "Government"] = "Assembly Elected President"
Gov_file_df.loc[Gov_file_df["Form of Government"] == 2.0, "Government"] = "Parliamentary"
Gov_file_df
# Out:
# <ipython-input-10-27dfee8b8c63>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Gov_file_df["Government"] = ""
# /Users/sarapatel/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/sarapatel/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#save cleaned government data as csv
Gov_file_df
Gov_file_df.to_csv("Resources/cleaned_gov_file.csv")

# %%
file = "../Happiness/Resources/avg_happiness.csv"
merge_ave_happiness = pd.read_csv(file)
merge_ave_happiness
# Out:
#          Country  Happiness Score_2015  Happiness Score_2016  \
# 0    Switzerland                 7.587                 7.509
# 1        Iceland                 7.561                 7.501
# 2        Denmark                 7.527                 7.526
# 3         Norway                 7.522                 7.498
# 4         Canada                 7.427                 7.404
# ..           ...                   ...                   ...
# 136       Rwanda                 3.465                 3.515
# 137        Benin                 3.340                 3.484
# 138        Syria                 3.006                 3.069
# 139      Burundi                 2.905                 2.905
# 140         Togo                 2.839                 3.303
#
#      Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 0                   7.494                 7.487                 7.480
# 1                   7.504                 7.495                 7.494
# ...

# %%
#merge happiness data with Government data by Country

merge_happiness_Gov = pd.merge(merge_ave_happiness, Gov_file_df, on="Country", how="left")
merge_happiness_Gov = merge_happiness_Gov.dropna()
merge_happiness_Gov.reset_index(inplace = True, drop = True)
merge_happiness_Gov
# Out:
#          Country  Happiness Score_2015  Happiness Score_2016  \
# 0    Switzerland                 7.587                 7.509
# 1        Iceland                 7.561                 7.501
# 2        Denmark                 7.527                 7.526
# 3         Norway                 7.522                 7.498
# 4         Canada                 7.427                 7.404
# ..           ...                   ...                   ...
# 117       Rwanda                 3.465                 3.515
# 118        Benin                 3.340                 3.484
# 119        Syria                 3.006                 3.069
# 120      Burundi                 2.905                 2.905
# 121         Togo                 2.839                 3.303
#
#      Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 0                   7.494                 7.487                 7.480
# 1                   7.504                 7.495                 7.494
# ...

# %%
#save new file as csv
merge_happiness_Gov
merge_happiness_Gov.to_csv("Resources/merge_happiness_gov.csv")

# %%
# DataFrom for all the SAME Governments

par = merge_happiness_Gov[merge_happiness_Gov["Government"] == "Parliamentary"]
direct = merge_happiness_Gov[merge_happiness_Gov["Government"] == "Direct Presidential"]
strong = merge_happiness_Gov[merge_happiness_Gov["Government"] == "Assembly Elected President"]

par.mean()
direct.mean()
strong.mean()
# Out:
# Happiness Score_2015       5.212429
# Happiness Score_2016       5.281143
# Happiness Score_2017       5.343286
# Happiness Score_2018       5.462571
# Happiness Score_2019       5.493571
# Avg Happiness              5.358600
# year                    2017.000000
# Form of Government         1.000000
# dtype: float64

# %%
# Getting Happiness Mean by form of government  
par_avg_happy = par["Avg Happiness"].mean()
direct_avg_happy = direct["Avg Happiness"].mean()
strong_avg_happy = strong["Avg Happiness"].mean()


avg_happiness = {"Governments" : ["Parliamentary","Direct Presidential","Assembly Elected President"],
                 "Average Happiness" : [par_avg_happy, direct_avg_happy, strong_avg_happy] }


print(par_avg_happy)
print(direct_avg_happy)
print(strong_avg_happy)

avg_happiness
# Out:
# 6.047290478960673
# 5.086257533504539
# 5.358599982888358
# {'Governments': ['Parliamentary',
#   'Direct Presidential',
#   'Assembly Elected President'],
#  'Average Happiness': [6.047290478960673,
#   5.086257533504539,
#   5.358599982888358]}

# %%
#create a data frame with the two values

avg_by_government = pd.DataFrame({"Governments":["Parliamentary","Direct Presidential","Assembly Elected President"],
                                "Average Happiness":[par_avg_happy, direct_avg_happy, strong_avg_happy] })
avg_by_government
# Out:
#                   Governments  Average Happiness
# 0               Parliamentary           6.047290
# 1         Direct Presidential           5.086258
# 2  Assembly Elected President           5.358600

# %%
# plot the average happiness results per form of Government

avg_by_government = pd.DataFrame.from_records(avg_happiness)
avg_by_government.plot.bar(y="Average Happiness", x="Governments", color=["green", "blue", "yellow"], figsize=(9,7))

plt.title("Form of Government Vs. Happiness", fontweight='bold', color = 'black', fontsize='15', horizontalalignment='center')
plt.xlabel("Form of Government", fontweight='bold', color = 'black', fontsize='12', horizontalalignment='center')
plt.ylabel("Happiness Average", fontweight='bold', color = 'black', fontsize='12', horizontalalignment='center')
plt.legend(loc="upper right")


plt.savefig("gov.png")

plt.show()

plt.savefig("../Images/gov.png", bbox_inches='tight')

# %%
# top ten countries by happiness average
merge_happiness_Gov.sort_values('Avg Happiness',ascending=False,inplace=True)
merge_happiness_Gov.head(10)
# Out:
#        Country  Happiness Score_2015  Happiness Score_2016  \
# 2      Denmark                 7.527                 7.526
# 3       Norway                 7.522                 7.498
# 5      Finland                 7.406                 7.413
# 0  Switzerland                 7.587                 7.509
# 1      Iceland                 7.561                 7.501
# 6  Netherlands                 7.378                 7.339
# 4       Canada                 7.427                 7.404
# 7       Sweden                 7.364                 7.291
# 8  New Zealand                 7.286                 7.334
# 9    Australia                 7.284                 7.313
#
#    Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 2                 7.522                 7.555                 7.600
# 3                 7.537                 7.594                 7.554
# 5                 7.469                 7.632                 7.769
# ...

# %%
# bottom ten countries by happiness average
merge_happiness_Gov.sort_values('Avg Happiness',ascending=True,inplace=True)
merge_happiness_Gov.head(10)
# Out:
#          Country  Happiness Score_2015  Happiness Score_2016  \
# 120      Burundi                 2.905                 2.905
# 119        Syria                 3.006                 3.069
# 117       Rwanda                 3.465                 3.515
# 111     Tanzania                 3.781                 3.666
# 116  Afghanistan                 3.575                 3.360
# 121         Togo                 2.839                 3.303
# 112   Madagascar                 3.681                 3.695
# 97      Botswana                 4.332                 3.974
# 88       Liberia                 4.571                 3.622
# 114       Guinea                 3.656                 3.607
#
#      Happiness Score_2017  Happiness Score_2018  Happiness Score_2019  \
# 120                 2.905                 2.905                 3.775
# 119                 3.462                 3.462                 3.462
# 117                 3.471                 3.408                 3.334
# ...
